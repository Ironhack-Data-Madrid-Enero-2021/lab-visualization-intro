# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# Answer all questions by drawing a graph. Then explain.

# %%
#import
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **0. Load seaborn dataset "tips"**

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 tips.sample(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 48        28.55  2.05    Male     No   Sun  Dinner     3
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# ...

# %% [markdown]
# **1. What is the prefered day for eating?**

# %%
x = (tips["day"].mode())

# %% [markdown]
# **2. What days of the week has more men than women payers?**

# %%
sns.countplot(x = tips.day, hue=tips.sex)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
g = sns.FacetGrid(tips, col="day",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
sns.countplot(x = tips.day, hue = tips.sex, palette = 'mako')
plt.title('Difference between gender in paying for days of the week')
# Out:
# Text(0.5, 1.0, 'Difference between gender in paying for days of the week')

# %%
sns.histplot(x=tips.day, hue=tips.sex, palette="Reds")
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
print(x)
# Out:
# 0    Sat
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# **3. Do you think bill amounts change considerably depending on smoking?**

# %%
sns.violinplot(x='smoker', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
g = sns.FacetGrid(tips, col="smoker",  row="sex")
g.map(sns.scatterplot, "tip", "total_bill")

# %%
sns.relplot(x = tips.total_bill, y = tips.tip, hue = tips.smoker)

# %%
sns.FacetGrid(tips, col="time",  row="smoker")
g.map(plt.hist, "total_bill")

# %% [markdown]
# **4. Is tip correlated to total_bill? Draw a scatter plot**

# %%
sns.scatterplot(x = tips.total_bill, y = tips.tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x="tip", y="total_bill", 
             hue="sex", style="sex", 
             data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# **BONUS**: Draw a graph of your choice with 2 numerical variables and 2 categorical variable (HINT: use `hue` and `style`). Do you find it useful?
